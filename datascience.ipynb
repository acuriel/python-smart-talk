# %%
import pandas as pd

# %%
li_jobs = pd.read_csv('li_jobs.csv', index_col=0)
li_jobs.describe()
# Out:
#                   WW          BG
# count       9.000000    9.000000
# mean   188794.444444  223.555556
# std    141450.454240  155.802047
# min     37705.000000   20.000000
# 25%     54740.000000  128.000000
# 50%    144397.000000  189.000000
# 75%    291535.000000  340.000000
# max    425714.000000  463.000000

# %%
li_jobs.plot(kind='bar', subplots=True, layout=(1,2))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000019CF19A3D48>,
# ...
#       dtype=object)
